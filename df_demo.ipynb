# %%
import pandas as pd

df1 = pd.read_csv('records_exp3w++_25_ASP.csv')
df2 = pd.read_csv('records_exp3w++_50_ASP.csv')
df3 = pd.read_csv('records_exp3w++_75_ASP.csv')
df4 = pd.read_csv('records_exp3w++_100_ASP.csv')

df_combined = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)
df_combined.to_csv('records_exp3w++_25-100_30_ASP.csv', index=False)

df1 = pd.read_csv('results_exp3w++_25_ASP.csv')
df2 = pd.read_csv('results_exp3w++_50_ASP.csv')
df3 = pd.read_csv('results_exp3w++_75_ASP.csv')
df4 = pd.read_csv('results_exp3w++_100_ASP.csv')

df_combined = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)
df_combined.to_csv('results_exp3w++_25-100_30_ASP.csv', index=False)

df1 = pd.read_csv('edge_data_exp3w++_25_ASP.csv')
df2 = pd.read_csv('edge_data_exp3w++_50_ASP.csv')
df3 = pd.read_csv('edge_data_exp3w++_75_ASP.csv')
df4 = pd.read_csv('edge_data_exp3w++_100_ASP.csv')

df_combined = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)
df_combined.to_csv('edge_data_exp3w++_25-100_30_ASP.csv', index=False)


# df.head()  # or simply type df and execute the cell 
# print(df.columns)

# %%
df = pd.read_csv('re.csv')

# %%
import pandas as pd
df = pd.read_csv('CSVs/results_150_several_ASP.csv')
# # print(df2.columns)
# df.head() 
# df.tail()


# for skill, group in df.groupby('skill_type'):
#     output_file = f'records_{skill}_150.csv'  
#     group.to_csv(f'CSVs/{output_file}', index=False)


print(df.columns)


# shape returns a tuple (number_of_rows, number_of_columns)
# num_rows = df.shape[0]
# num_columns = df.shape[1]
# print(f"The DataFrame has {num_rows} rows and {num_columns} columns.")

# unique_values = df2['skill_type'].unique()
# print("Unique values in 'skill_type':", unique_values)

# non_string_entries = df2[df2['skill_type'].apply(lambda x: isinstance(x, float))]
# print(non_string_entries)

# nan_entries = df2[df2['skill_type'].isna()]
# print("Rows with NaN values in 'skill_type':")
# print(nan_entries)
# Out:
# Index(['num_agents', 'skill_type', 'network', 'clustering_coefficient',
#        'average_path_length', 'degree_distribution', 'degree_histogram',
#        'cooperation_proportion', 'density', 'assortativity', 'modularity',
#        'edge_weight'],
#       dtype='object')
